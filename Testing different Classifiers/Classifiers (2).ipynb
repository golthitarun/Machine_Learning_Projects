# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import normalize

# %%
data = pd.read_csv("car.data",header = None,names = ['buying','maint','doors','persons','lug_boot','safety','cat'])

# %%
print data.info()
print data.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1728 entries, 0 to 1727
# Data columns (total 7 columns):
# buying      1728 non-null object
# maint       1728 non-null object
# doors       1728 non-null object
# persons     1728 non-null object
# lug_boot    1728 non-null object
# safety      1728 non-null object
# cat         1728 non-null object
# dtypes: object(7)
# memory usage: 94.6+ KB
# None
#   buying  maint doors persons lug_boot safety    cat
# 0  vhigh  vhigh     2       2    small    low  unacc
# 1  vhigh  vhigh     2       2    small    med  unacc
# 2  vhigh  vhigh     2       2    small   high  unacc
# 3  vhigh  vhigh     2       2      med    low  unacc
# 4  vhigh  vhigh     2       2      med    med  unacc
# 5  vhigh  vhigh     2       2      med   high  unacc
# 6  vhigh  vhigh     2       2      big    low  unacc
# 7  vhigh  vhigh     2       2      big    med  unacc
# 8  vhigh  vhigh     2       2      big   high  unacc
# 9  vhigh  vhigh     2       4    small    low  unacc

# %%
data['buying'] = data['buying'].map({'vhigh' : 3,'high' : 2, 'med' : 1, 'low' : 0})
data['maint'] = data['maint'].map({'vhigh' : 3,'high' : 2, 'med' : 1, 'low' : 0})
data['doors'] = data['doors'].map({'5more' : 5, '2' : 2,'3' : 3, '4' : 4})
data['persons'] = data['persons'].map({'more' : 5, '2' : 2, '4' : 4})
data['lug_boot'] = data['lug_boot'].map({'small' : 0,'med' : 1, 'big' : 2})
data['safety'] = data['safety'].map({'low' : 0,'med' : 1, 'high' : 2})
data['cat'] = data['cat'].map({'unacc' : 0,'acc' : 1,'good' : 2,'vgood' : 3})

# %%
#msk = np.random.rand(len(data)) < 0.7
#train = data[msk]
#test = data[~msk]
train =data.sample(frac = 0.7)
test = data.loc[~data.index.isin(train.index)]
train
# Out:
#       buying  maint  doors  persons  lug_boot  safety  cat
# 712        2      1      4        4         0       1    0
# 324        3      0      2        2         0       0    0
# 671        2      1      2        5         1       2    1
# 434        2      3      2        2         0       2    0
# 1520       0      1      2        2         2       2    0
# 101        3      3      5        5         0       2    0
# 261        3      1      3        5         0       0    0
# 458        2      3      2        5         2       2    0
# 1285       1      0      5        4         2       1    2
# 1679       0      0      4        2         1       2    0
# 1122       1      1      3        4         2       0    0
# 546        2      2      2        2         2       0    0
# 1533       0      1      2        5         1       0    0
# 220        3      1      2        2         1       1    0
# 1071       1      2      5        5         0       0    0
# 473        2      3      3        4         1       2    0
# 1329       0      3      3        2         2       0    0
# 321        3      1      5        5         2       0    0
# 1384       0      3      5        2         2       1    0
# 376        3      0      3        5         2       1    1
# 1203       1      0      2        4         2       0    0
# 1325       0      3      3        2         0       2    0
# 691        2      1      3        4         2       1    1
# 1067       1      2      5        4         1       2    1
# 252        3      1      3        4         0       0    0
# 1585       0      1      4        5         0       1    1
# 1256       1      0      4        4         1       2    3
# 746        2      1      5        4         2       2    1
# 741        2      1      5        4         1       0    0
# 1390       0      3      5        4         1       1    1
# ...      ...    ...    ...      ...       ...     ...  ...
# 446        2      3      2        4         1       2    0
# 1567       0      1      4        2         0       1    0
# 637        2      2      5        4         2       1    1
# 668        2      1      2        5         0       2    0
# 94         3      3      5        4         1       1    0
# 75         3      3      4        5         1       0    0
# 1727       0      0      5        5         2       2    3
# 739        2      1      5        4         0       1    0
# 1495       0      2      5        4         0       1    1
# 1572       0      1      4        2         2       0    0
# 1492       0      2      5        2         2       1    0
# 839        2      0      5        2         0       2    0
# 1266       1      0      4        5         2       0    0
# 436        2      3      2        2         1       1    0
# 1137       1      1      4        2         1       0    0
# 1045       1      2      4        5         0       1    0
# 84         3      3      5        2         1       0    0
# 553        2      2      2        4         1       1    0
# 90         3      3      5        4         0       0    0
# 386        3      0      4        2         2       2    0
# 1720       0      0      5        5         0       1    1
# 1653       0      0      3        2         2       0    0
# 602        2      2      4        2         2       2    0
# 1274       1      0      5        2         1       2    0
# 1320       0      3      2        5         2       0    0
# 625        2      2      5        2         1       1    0
# 870        1      3      2        2         2       0    0
# 1450       0      2      3        5         0       1    1
# 1326       0      3      3        2         1       0    0
# 1219       1      0      3        2         1       1    0
#
# [1210 rows x 7 columns]

# %%
from sklearn.metrics import accuracy_score, log_loss
from sklearn import tree
from sklearn import linear_model
from sklearn import svm
from sklearn.neural_network import MLPClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
x_train = train[train.columns[0:6]]
y_train  = train[train.columns[6]]
x_test = test[test.columns[0:6]]
y_test = test[test.columns[6]]
x_train
# Out:
#       buying  maint  doors  persons  lug_boot  safety
# 712        2      1      4        4         0       1
# 324        3      0      2        2         0       0
# 671        2      1      2        5         1       2
# 434        2      3      2        2         0       2
# 1520       0      1      2        2         2       2
# 101        3      3      5        5         0       2
# 261        3      1      3        5         0       0
# 458        2      3      2        5         2       2
# 1285       1      0      5        4         2       1
# 1679       0      0      4        2         1       2
# 1122       1      1      3        4         2       0
# 546        2      2      2        2         2       0
# 1533       0      1      2        5         1       0
# 220        3      1      2        2         1       1
# 1071       1      2      5        5         0       0
# 473        2      3      3        4         1       2
# 1329       0      3      3        2         2       0
# 321        3      1      5        5         2       0
# 1384       0      3      5        2         2       1
# 376        3      0      3        5         2       1
# 1203       1      0      2        4         2       0
# 1325       0      3      3        2         0       2
# 691        2      1      3        4         2       1
# 1067       1      2      5        4         1       2
# 252        3      1      3        4         0       0
# 1585       0      1      4        5         0       1
# 1256       1      0      4        4         1       2
# 746        2      1      5        4         2       2
# 741        2      1      5        4         1       0
# 1390       0      3      5        4         1       1
# ...      ...    ...    ...      ...       ...     ...
# 446        2      3      2        4         1       2
# 1567       0      1      4        2         0       1
# 637        2      2      5        4         2       1
# 668        2      1      2        5         0       2
# 94         3      3      5        4         1       1
# 75         3      3      4        5         1       0
# 1727       0      0      5        5         2       2
# 739        2      1      5        4         0       1
# 1495       0      2      5        4         0       1
# 1572       0      1      4        2         2       0
# 1492       0      2      5        2         2       1
# 839        2      0      5        2         0       2
# 1266       1      0      4        5         2       0
# 436        2      3      2        2         1       1
# 1137       1      1      4        2         1       0
# 1045       1      2      4        5         0       1
# 84         3      3      5        2         1       0
# 553        2      2      2        4         1       1
# 90         3      3      5        4         0       0
# 386        3      0      4        2         2       2
# 1720       0      0      5        5         0       1
# 1653       0      0      3        2         2       0
# 602        2      2      4        2         2       2
# 1274       1      0      5        2         1       2
# 1320       0      3      2        5         2       0
# 625        2      2      5        2         1       1
# 870        1      3      2        2         2       0
# 1450       0      2      3        5         0       1
# 1326       0      3      3        2         1       0
# 1219       1      0      3        2         1       1
#
# [1210 rows x 6 columns]

# %%
classifiers = []
clf = tree.DecisionTreeClassifier()
#clf.set_params(max_features = "auto")
dt_clf = clf.fit(x_train,y_train)
dt_predict = dt_clf.predict(x_test)
dt_acc = accuracy_score(y_test,dt_predict)
#param =  dt_clf.get_params()
classifiers.append(clf)

print 'DecisionTree accuracy :', dt_acc
#print param 

clf = linear_model.Perceptron()
pt_clf = clf.fit(x_train,y_train)
pt_predict = pt_clf.predict(x_test)
pt_acc = accuracy_score(y_test,pt_predict)
print 'Perceptron accuracy :',pt_acc
classifiers.append(clf)

clf = MLPClassifier()
nn_clf = clf.fit(x_train,y_train)
nn_predict = nn_clf.predict(x_test)
nn_acc = accuracy_score(y_test,nn_predict)
print 'Neural Net accuracy :',nn_acc
classifiers.append(clf)

clf = svm.SVC()
svm_clf = clf.fit(x_train,y_train)
svm_predict = svm_clf.predict(x_test)
svm_acc = accuracy_score(y_test,svm_predict)
print 'SVM accuracy :',svm_acc
classifiers.append(clf)




clf = MultinomialNB()
nb_clf = clf.fit(x_train,y_train)
nb_predict = nb_clf.predict(x_test)
nb_acc = accuracy_score(y_test,nb_predict)
print 'naïve Bayes accuracy :',nb_acc
classifiers.append(clf)



clf = LogisticRegression()
lr_clf = clf.fit(x_train,y_train)
lr_predict = lr_clf.predict(x_test)
lr_acc = accuracy_score(y_test,lr_predict)
print 'Logistic Regression accuracy :',lr_acc
classifiers.append(clf)



clf = KNeighborsClassifier(3)
knn_clf = clf.fit(x_train,y_train)
knn_predict = knn_clf.predict(x_test)
knn_acc = accuracy_score(y_test,knn_predict)
param =  knn_clf.get_params()
print 'k-Nearest Neighbors accuracy :',knn_acc
classifiers.append(clf)



clf = BaggingClassifier()
bg_clf = clf.fit(x_train,y_train)
bg_predict = bg_clf.predict(x_test)
bg_acc = accuracy_score(y_test,bg_predict)
print 'Bagging accuracy :',bg_acc
classifiers.append(clf)

clf = RandomForestClassifier()
rf_clf = clf.fit(x_train,y_train)
rf_predict = rf_clf.predict(x_test)
rf_acc = accuracy_score(y_test,rf_predict)
print 'Random Forests :',rf_acc
classifiers.append(clf)

clf = AdaBoostClassifier()
ada_clf = clf.fit(x_train,y_train)
ada_predict = ada_clf.predict(x_test)
ada_acc = accuracy_score(y_test,ada_predict)
print 'AdaBoost accuracy :',ada_acc

classifiers.append(clf)

clf = GradientBoostingClassifier()
gb_clf = clf.fit(x_train,y_train)
gb_predict = gb_clf.predict(x_test)
gb_acc = accuracy_score(y_test,gb_predict)
print 'Gradient Boosting accuracy :',gb_acc
classifiers.append(clf)
# Out:
# DecisionTree accuracy : 0.982625482625
# Perceptron accuracy : 0.824324324324
# Neural Net accuracy : 0.911196911197
# SVM accuracy : 0.96138996139
# naïve Bayes accuracy : 0.698841698842
# Logistic Regression accuracy : 0.816602316602
# k-Nearest Neighbors accuracy : 0.920849420849
# Bagging accuracy : 0.972972972973
# Random Forests : 0.96332046332
# AdaBoost accuracy : 0.855212355212
# Gradient Boosting accuracy : 0.986486486486

# %%
from sklearn.model_selection import cross_val_score
clf = tree.DecisionTreeClassifier()
clf.set_params(max_leaf_nodes = 50,max_depth = 10, max_features = None)
dt_clf = clf.fit(x_train,y_train)
dt_predict = dt_clf.predict(x_test)
dt_acc = accuracy_score(y_test,dt_predict)
param =  dt_clf.get_params()

accuracy = cross_val_score(clf, x_train , y_train, cv=10,scoring = 'accuracy')
f_score = cross_val_score(clf, x_train , y_train, cv=10,scoring = 'f1_micro')
print accuracy.mean(), " - ",f_score.mean()
# Out:
# 0.966042747172  -  0.964403292761

# %%
clf = linear_model.Perceptron()
clf.set_params(n_iter = 15,alpha = 0.01)
pt_clf = clf.fit(x_train,y_train)
pt_predict = pt_clf.predict(x_test)
pt_acc = accuracy_score(y_test,pt_predict)

accuracy = cross_val_score(clf, x_train , y_train, cv=10,scoring = 'accuracy')
f_score = cross_val_score(clf, x_train , y_train, cv=10,scoring = 'f1_micro')
print accuracy.mean(), " - ",f_score.mean()

#print pt_acc
# Out:
# 0.739442414089  -  0.739442414089

# %%
clf = MLPClassifier()
clf.set_params(hidden_layer_sizes =(25,50), max_iter = 10,alpha = 0.1, momentum = 0.1)
nn_clf = clf.fit(x_train,y_train)
nn_predict = nn_clf.predict(x_test)
nn_acc = accuracy_score(y_test,nn_predict)

accuracy = cross_val_score(clf, x_train , y_train, cv=10,scoring = 'accuracy')
f_score = cross_val_score(clf, x_train , y_train, cv=10,scoring = 'f1_micro')
print accuracy.mean(), " - ",f_score.mean()
# Out:
# /home/tharunn/anaconda3/envs/py27/lib/python2.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations reached and the optimization hasn't converged yet.
#   % (), ConvergenceWarning)
# 0.714007371286  -  0.716534368936

# %%
clf = MLPClassifier()
clf.set_params(hidden_layer_sizes =(100,100,100,100), max_iter = 100,alpha = 0.3, activation='relu', momentum = 0.7)
nn_clf = clf.fit(x_train,y_train)
nn_predict = nn_clf.predict(x_test)
nn_acc = accuracy_score(y_test,nn_predict)

accuracy = cross_val_score(clf, x_train , y_train, cv=10,scoring = 'accuracy')
f_score = cross_val_score(clf, x_train , y_train, cv=10,scoring = 'f1_micro')
print accuracy.mean(), " - ",f_score.mean()
# Out:
# 0.926444558344  -  0.936184191046

# %%
clf = svm.SVC()
clf.set_params(C = 1, kernel = "linear")
svm_clf = clf.fit(x_train,y_train)
svm_predict = svm_clf.predict(x_test)
svm_acc = accuracy_score(y_test,svm_predict)
accuracy = cross_val_score(clf, x_train , y_train, cv=10,scoring = 'accuracy')
f_score = cross_val_score(clf, x_train , y_train, cv=10,scoring = 'f1_micro')
print accuracy.mean(), " - ",f_score.mean()
# Out:
# 0.863529276231  -  0.863529276231

# %%
clf = MultinomialNB()
clf.set_params(alpha = 0)
nb_clf = clf.fit(x_train,y_train)
nb_predict = nb_clf.predict(x_test)
nb_acc = accuracy_score(y_test,nb_predict)
accuracy = cross_val_score(clf, x_train , y_train, cv=10,scoring = 'accuracy')
f_score = cross_val_score(clf, x_train , y_train, cv=10,scoring = 'f1_micro')
print accuracy.mean(), " - ",f_score.mean()
# Out:
# 0.709137101855  -  0.709137101855

# %%
clf = LogisticRegression()
clf.set_params(C = 10, max_iter = 10)
lr_clf = clf.fit(x_train,y_train)
lr_predict = lr_clf.predict(x_test)
lr_acc = accuracy_score(y_test,lr_predict)
accuracy = cross_val_score(clf, x_train , y_train, cv=10,scoring = 'accuracy')
f_score = cross_val_score(clf, x_train , y_train, cv=10,scoring = 'f1_micro')
print accuracy.mean(), " - ",f_score.mean()
# Out:
# 0.814708858476  -  0.814708858476

# %%
clf = KNeighborsClassifier()
clf.set_params(n_neighbors= 1,leaf_size = 1)
knn_clf = clf.fit(x_train,y_train)
knn_predict = knn_clf.predict(x_test)
knn_acc = accuracy_score(y_test,knn_predict)
param =  knn_clf.get_params()
accuracy = cross_val_score(clf, x_train , y_train, cv=10,scoring = 'accuracy')
f_score = cross_val_score(clf, x_train , y_train, cv=10,scoring = 'f1_micro')
print accuracy.mean(), " - ",f_score.mean()
# Out:
# 0.861979935183  -  0.861979935183

# %%
clf = BaggingClassifier()
clf.set_params(n_estimators = 1,max_samples = 1)
bg_clf = clf.fit(x_train,y_train)
bg_predict = bg_clf.predict(x_test)
bg_acc = accuracy_score(y_test,bg_predict)
accuracy = cross_val_score(clf, x_train , y_train, cv=10,scoring = 'accuracy')
f_score = cross_val_score(clf, x_train , y_train, cv=10,scoring = 'f1_micro')
print accuracy.mean(), " - ",f_score.mean()
# Out:
# 0.569195813815  -  0.587490977843

# %%
clf = RandomForestClassifier()
clf.set_params(n_estimators = 1, max_depth = 1)
rf_clf = clf.fit(x_train,y_train)
rf_predict = rf_clf.predict(x_test)
rf_acc = accuracy_score(y_test,rf_predict)
accuracy = cross_val_score(clf, x_train , y_train, cv=10,scoring = 'accuracy')
f_score = cross_val_score(clf, x_train , y_train, cv=10,scoring = 'f1_micro')
print accuracy.mean(), " - ",f_score.mean()
# Out:
# 0.700885286786  -  0.700885286786

# %%
clf = AdaBoostClassifier()
clf.set_params(n_estimators = 1, learning_rate = 1)
ada_clf = clf.fit(x_train,y_train)
ada_predict = ada_clf.predict(x_test)
ada_acc = accuracy_score(y_test,ada_predict)
accuracy = cross_val_score(clf, x_train , y_train, cv=10,scoring = 'accuracy')
f_score = cross_val_score(clf, x_train , y_train, cv=10,scoring = 'f1_micro')
print accuracy.mean(), " - ",f_score.mean()
# Out:
# 0.700885286786  -  0.700885286786

# %%
clf = GradientBoostingClassifier()
clf.set_params(n_estimators = 1,learning_rate = 1)
gb_clf = clf.fit(x_train,y_train)
gb_predict = gb_clf.predict(x_test)
gb_acc = accuracy_score(y_test,gb_predict)
accuracy = cross_val_score(clf, x_train , y_train, cv=10,scoring = 'accuracy')
f_score = cross_val_score(clf, x_train , y_train, cv=10,scoring = 'f1_micro')
print accuracy.mean(), " - ",f_score.mean()
# Out:
# 0.820672515076  -  0.820672515076

# %%
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import label_binarize
clf = svm.SVC()
#y_train = label_binarize(y_train,classes = [0,1,2,3])
scores = cross_val_score(clf, x_train , y_train, cv=10,scoring = 'f1_micro')

# %%
print "accuracy","        ","F-score"
for clf in classifiers:
    accuracy = cross_val_score(clf, x_train , y_train, cv=10,scoring = 'accuracy')
    f_score = cross_val_score(clf, x_train , y_train, cv=10,scoring = 'f1_micro')
    print accuracy.mean(), "  ",f_score.mean()
# Out:
# accuracy          F-score
# 0.968556868523    0.966883311958
# 0.731359585411    0.731359585411
# 0.933022139247    0.933835040075
# 0.958686477744    0.958686477744
# 0.709130437854    0.709130437854
# 0.801498580418    0.801498580418
# 0.920746504232    0.920746504232
# 0.965270615346    0.969390312005
# 0.958645149737    0.952818248907
# 0.833628923596    0.833628923596
# 0.981768154534    0.981768154534
